# %%
from xmitgcm import llcreader
# model = llcreader.ECCOPortalLLC4320Model()
model = llcreader.ECCOPortalLLC2160Model()
ds = model.get_dataset(varnames=['SIuice','SIvice','SIheff','SIarea'])

# %%
dsf6=ds.sel(face=6)

# %%
dsf6t0=dsf6.isel(time=slice(None, 20))

# %%
SIheff=dsf6t0['SIheff']

# %%
SIheff[0].plot(robust=True)
